# %%
import pandas as pd

data = {
    "Name": ["Aman", "Riya", "Kabir", "Sneha", "Arjun"],
    "Age": [21, 22, 21, 23, 22],
    "Marks": [85, 92, 78, 88, 95],
    "City": ["Delhi", "Mumbai", "Delhi", "Pune", "Mumbai"]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age  Marks    City
# 0   Aman   21     85   Delhi
# 1   Riya   22     92  Mumbai
# 2  Kabir   21     78   Delhi
# 3  Sneha   23     88    Pune
# 4  Arjun   22     95  Mumbai

# %%
df[df["Marks"] > 85]
# Out:
#     Name  Age  Marks    City
# 1   Riya   22     92  Mumbai
# 3  Sneha   23     88    Pune
# 4  Arjun   22     95  Mumbai

# %%
df[["Name","Marks"]]
# Out:
#   Cell In[14], line 2
#     df.[Name, Marks]
#        ^
# SyntaxError: invalid syntax

# %%
df["Marks"].mean()
# Out:
# np.float64(87.6)

# %%
df.groupby("City")["Marks"].mean()
# Out:
# City
# Delhi     81.5
# Mumbai    93.5
# Pune      88.0
# Name: Marks, dtype: float64

# %%
df["Grade"] = df["Marks"]/10
print(df)
# Out:
#     Name  Age  Marks    City  Grade
# 0   Aman   21     85   Delhi    8.5
# 1   Riya   22     92  Mumbai    9.2
# 2  Kabir   21     78   Delhi    7.8
# 3  Sneha   23     88    Pune    8.8
# 4  Arjun   22     95  Mumbai    9.5

# %%
df.groupby("City").size()     

# OR

df["City"].value_counts()
# Out:
# City
# Delhi     2
# Mumbai    2
# Pune      1
# Name: count, dtype: int64
